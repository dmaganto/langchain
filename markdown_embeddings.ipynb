# %%
# !python3 -m venv venv
# !source venv/bin/activate
# !pip3 install markdown langchain opensearch-py
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/PyYAML-6.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/PyYAML-6.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/click-8.1.7.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/packaging-23.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/MarkupSafe-2.1.3.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: markdown in /opt/homebrew/lib/python3.11/site-packages (3.5.1)
# Requirement already satisfied: langchain in /opt/homebrew/lib/python3.11/site-packages (0.0.331)
# Requirement already satisfied: opensearch-py in /opt/homebrew/lib/python3.11/site-packages (2.3.2)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: anyio<4.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (3.7.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (0.6.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (1.33)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.52 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (0.0.60)
# Requirement already satisfied: numpy<2,>=1 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (1.24.2)
# Requirement already satisfied: pydantic<3,>=1 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (2.4.2)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (2.28.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: urllib3>=1.26.9 in /opt/homebrew/lib/python3.11/site-packages (from opensearch-py) (1.26.15)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.11/site-packages (from opensearch-py) (1.16.0)
# Requirement already satisfied: python-dateutil in /opt/homebrew/lib/python3.11/site-packages (from opensearch-py) (2.8.2)
# Requirement already satisfied: certifi>=2022.12.07 in /opt/homebrew/lib/python3.11/site-packages (from opensearch-py) (2022.12.7)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.11/site-packages (from anyio<4.0->langchain) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /opt/homebrew/lib/python3.11/site-packages (from anyio<4.0->langchain) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.20.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3,>=1->langchain) (4.8.0)
# Requirement already satisfied: packaging>=17.0 in /opt/homebrew/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.7,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.0.0)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/PyYAML-6.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/click-8.1.7.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/packaging-23.2.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/MarkupSafe-2.1.3.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/PyYAML-6.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/PyYAML-6.0.1.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/certifi-2023.7.22.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/PyYAML-6.0.1.dist-info due to invalid metadata entry 'name'

# %%
# Load environment variables

from dotenv import load_dotenv,find_dotenv
load_dotenv(find_dotenv())
OPENAI_API_KEY="XXXXXXXXXX"

# %%
import markdown
from langchain.text_splitter import MarkdownHeaderTextSplitter
from langchain.text_splitter import RecursiveCharacterTextSplitter


from pathlib import Path

markdown_document = ""
pathlist = Path('docs').glob('**/*.md')
for path in pathlist:
     # because path is object not string
     path_in_str = str(path)
     f = open(path_in_str, 'r')
     markdown_document += f.read()

headers_to_split_on = [
    ("#", "Header 1"),
    ("##", "Header 2"),
]

# MD splits
markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on=headers_to_split_on)
md_header_splits = markdown_splitter.split_text(markdown_document)

# Char-level splits

chunk_size = 250
chunk_overlap = 30
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=chunk_size, chunk_overlap=chunk_overlap
)

# Split
splits = text_splitter.split_documents(md_header_splits)

# %%
# Add metadata information needed for Chroma
for i, text in enumerate(splits): text.metadata["source"] = f"{i}-pl"
splits
# Out:
# [Document(page_content='An h1 header\n============  \nParagraphs are separated by a blank line.  \n2nd paragraph. *Italic*, **bold**, and `monospace`. Itemized lists\nlook like:  \n* this one\n* that one\n* the other one', metadata={'source': '0-pl'}),
#  Document(page_content='* that one\n* the other one  \nNote that --- not considering the asterisk --- the actual text\ncontent starts at 4-columns in.  \n> Block quotes are\n> written like so.\n>\n> They can span multiple paragraphs,\n> if you like.', metadata={'source': '1-pl'}),
#  Document(page_content='> if you like.  \nUse 3 dashes for an em-dash. Use 2 dashes for ranges (ex., "it\'s all\nin chapters 12--14"). Three dots ... will be converted to an ellipsis.\nUnicode is supported. ☺  \nAn h2 header\n------------  \nHere\'s a numbered list:', metadata={'source': '2-pl'}),
#  Document(page_content="Here's a numbered list:  \n1. first item\n2. second item\n3. third item  \nNote again how the actual text starts at 4 columns in (4 characters\nfrom the left side). Here's a code sample:", metadata={'source': '3-pl'}),
#  Document(page_content='for i in 1 .. 10 { do-something(i) }  \nAs you probably guessed, indented 4 spaces. By the way, instead of\nindenting the block, you can use delimited blocks, if you like:  \n~~~\ndefine foobar() {\nprint "Welcome to flavor country!";\n}\n~~~', metadata={'Header 1': 'Let me re-iterate ...', 'source': '4-pl'}),
#  Document(page_content='}\n~~~  \n(which makes copying & pasting easier). You can optionally mark the\ndelimited block for Pandoc to syntax highlight it:  \n~~~python\nimport time', metadata={'Header 1': 'Let me re-iterate ...', 'source': '5-pl'}),
#  Document(page_content='for i in range(10):', metadata={'Header 1': 'Quick, count to ten!', 'source': '6-pl'}),
#  Document(page_content='time.sleep(0.5)\nprint i\n~~~  \n### An h3 header ###  \nNow a nested list:  \n1. First, get these ingredients:  \n* carrots\n* celery\n* lentils  \n2. Boil some water.  \n3. Dump everything in the pot and follow\nthis algorithm:  \nfind wooden spoon\nuncover pot', metadata={'Header 1': '(but not *too* quick)', 'source': '7-pl'}),
#  Document(page_content='find wooden spoon\nuncover pot\nstir\ncover pot\nbalance wooden spoon precariously on pot handle\nwait 10 minutes\ngoto first step (or shut off burner when done)  \nDo not bump wooden spoon or it will fall.', metadata={'Header 1': '(but not *too* quick)', 'source': '8-pl'}),
#  Document(page_content="Notice again how text always lines up on 4-space indents (including\nthat last line which continues item 3 above).  \nHere's a link to [a website](http://foo.bar), to a [local\ndoc](local-doc.html), and to a [section heading in the current", metadata={'Header 1': '(but not *too* quick)', 'source': '9-pl'}),
#  Document(page_content="doc](#an-h2-header). Here's a footnote [^1].  \n[^1]: Footnote text goes here.  \nTables can look like this:  \nsize  material      color\n----  ------------  ------------\n9     leather       brown\n10    hemp canvas   natural", metadata={'Header 1': '(but not *too* quick)', 'source': '10-pl'}),
#  Document(page_content="10    hemp canvas   natural\n11    glass         transparent  \nTable: Shoes, their sizes, and what they're made of  \n(The above is the caption for the table.) Pandoc also supports\nmulti-line tables:  \n--------  -----------------------\nkeyword   text", metadata={'Header 1': '(but not *too* quick)', 'source': '11-pl'}),
#  Document(page_content="keyword   text\n--------  -----------------------\nred       Sunsets, apples, and\nother red or reddish\nthings.  \ngreen     Leaves, grass, frogs\nand other things it's\nnot easy being.\n--------  -----------------------  \nA horizontal rule follows.", metadata={'Header 1': '(but not *too* quick)', 'source': '12-pl'}),
#  Document(page_content='A horizontal rule follows.  \n***  \nHere\'s a definition list:  \napples\n: Good for making applesauce.\noranges\n: Citrus!\ntomatoes\n: There\'s no "e" in tomatoe.  \nAgain, text is indented 4 spaces. (Put a blank line between each', metadata={'Header 1': '(but not *too* quick)', 'source': '13-pl'}),
#  Document(page_content='term/definition pair to spread things out more.)  \nHere\'s a "line block":  \n| Line one\n|   Line too\n| Line tree  \nand images can be specified like so:  \n![example image](example-image.jpg "An exemplary image")', metadata={'Header 1': '(but not *too* quick)', 'source': '14-pl'}),
#  Document(page_content='Inline math equations go in like so: $\\omega = d\\phi / dt$. Display\nmath should get its own line and be put in in double-dollarsigns:  \n$$I = \\int \\rho R^{2} dV$$  \nAnd note that you can backslash-escape any punctuation characters', metadata={'Header 1': '(but not *too* quick)', 'source': '15-pl'}),
#  Document(page_content='which you wish to be displayed literally, ex.: \\`foo\\`, \\*bar\\*, etc.', metadata={'Header 1': '(but not *too* quick)', 'source': '16-pl'}),
#  Document(page_content="~~strikethrough~~  \n**Note:** This document is itself written using Markdown; you\ncan [see the source for it by adding '.text' to the URL](/projects/markdown/syntax.text).  \n----", metadata={'Header 1': 'Markdown: Syntax', 'source': '17-pl'}),
#  Document(page_content='### Philosophy  \nMarkdown is intended to be as easy-to-read and easy-to-write as is feasible.  \nReadability, however, is emphasized above all else. A Markdown-formatted\ndocument should be publishable as-is, as plain text, without looking', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '18-pl'}),
#  Document(page_content="like it's been marked up with tags or formatting instructions. While\nMarkdown's syntax has been influenced by several existing text-to-HTML", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '19-pl'}),
#  Document(page_content='filters -- including [Setext](http://docutils.sourceforge.net/mirror/setext.html), [atx](http://www.aaronsw.com/2002/atx/), [Textile](http://textism.com/tools/textile/), [reStructuredText](http://docutils.sourceforge.net/rst.html),', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '20-pl'}),
#  Document(page_content="[Grutatext](http://www.triptico.com/software/grutatxt.html), and [EtText](http://ettext.taint.org/doc/) -- the single biggest source of\ninspiration for Markdown's syntax is the format of plain text email.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '21-pl'}),
#  Document(page_content='### Paragraphs and Line Breaks  \nA paragraph is simply one or more consecutive lines of text, separated\nby one or more blank lines. (A blank line is any line that looks like a\nblank line -- a line containing nothing but spaces or tabs is considered', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '22-pl'}),
#  Document(page_content='blank.) Normal paragraphs should not be indented with spaces or tabs.  \nThe implication of the "one or more consecutive lines of text" rule is\nthat Markdown supports "hard-wrapped" text paragraphs. This differs', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '23-pl'}),
#  Document(page_content='significantly from most other text-to-HTML formatters (including Movable\nType\'s "Convert Line Breaks" option) which translate every line break\ncharacter in a paragraph into a `<br />` tag.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '24-pl'}),
#  Document(page_content='When you *do* want to insert a `<br />` break tag using Markdown, you\nend a line with two or more spaces, then type return.  \n### Headers  \nMarkdown supports two styles of headers, [Setext] [1] and [atx] [2].', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '25-pl'}),
#  Document(page_content='Optionally, you may "close" atx-style headers. This is purely\ncosmetic -- you can use this if you think it looks better. The\nclosing hashes don\'t even need to match the number of hashes\nused to open the header. (The number of opening hashes', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '26-pl'}),
#  Document(page_content="determines the header level.)  \n### Blockquotes  \nMarkdown uses email-style `>` characters for blockquoting. If you're\nfamiliar with quoting passages of text in an email message, then you", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '27-pl'}),
#  Document(page_content='know how to create a blockquote in Markdown. It looks best if you hard\nwrap the text and put a `>` before every line:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '28-pl'}),
#  Document(page_content='> consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\n> Vestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.\n>\n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '29-pl'}),
#  Document(page_content='> id sem consectetuer libero luctus adipiscing.  \nMarkdown allows you to be lazy and only put the `>` before the first\nline of a hard-wrapped paragraph:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '30-pl'}),
#  Document(page_content='consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\nVestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.  \n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '31-pl'}),
#  Document(page_content='id sem consectetuer libero luctus adipiscing.  \nBlockquotes can be nested (i.e. a blockquote-in-a-blockquote) by\nadding additional levels of `>`:  \n> This is the first level of quoting.\n>\n> > This is nested blockquote.\n>\n> Back to the first level.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '32-pl'}),
#  Document(page_content='> Back to the first level.  \nBlockquotes can contain other Markdown elements, including headers, lists,\nand code blocks:  \n> ## This is a header.\n>\n> 1.   This is the first list item.\n> 2.   This is the second list item.\n>', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '33-pl'}),
#  Document(page_content='>\n> Here\'s some example code:\n>\n>     return shell_exec("echo $input | $markdown_script");  \nAny decent text editor should make email-style quoting easy. For\nexample, with BBEdit, you can make a selection and choose Increase', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '34-pl'}),
#  Document(page_content='Quote Level from the Text menu.  \n### Lists  \nMarkdown supports ordered (numbered) and unordered (bulleted) lists.  \nUnordered lists use asterisks, pluses, and hyphens -- interchangably\n-- as list markers:  \n*   Red\n*   Green\n*   Blue', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '35-pl'}),
#  Document(page_content='*   Red\n*   Green\n*   Blue  \nis equivalent to:  \n+   Red\n+   Green\n+   Blue  \nand:  \n-   Red\n-   Green\n-   Blue  \nOrdered lists use numbers followed by periods:  \n1.  Bird\n2.  McHale\n3.  Parish', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '36-pl'}),
#  Document(page_content="2.  McHale\n3.  Parish  \nIt's important to note that the actual numbers you use to mark the\nlist have no effect on the HTML output Markdown produces. The HTML\nMarkdown produces from the above list is:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '37-pl'}),
#  Document(page_content="If you instead wrote the list in Markdown like this:  \n1.  Bird\n1.  McHale\n1.  Parish  \nor even:  \n3. Bird\n1. McHale\n8. Parish  \nyou'd get the exact same HTML output. The point is, if you want to,", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '38-pl'}),
#  Document(page_content="you can use ordinal numbers in your ordered Markdown lists, so that\nthe numbers in your source match the numbers in your published HTML.\nBut if you want to be lazy, you don't have to.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '39-pl'}),
#  Document(page_content='To make lists look nice, you can wrap items with hanging indents:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.\nAliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '40-pl'}),
#  Document(page_content="*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.  \nBut if you want to be lazy, you don't have to:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '41-pl'}),
#  Document(page_content='Aliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.\n*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '42-pl'}),
#  Document(page_content='List items may consist of multiple paragraphs. Each subsequent\nparagraph in a list item must be indented by either 4 spaces\nor one tab:  \n1.  This is a list item with two paragraphs. Lorem ipsum dolor', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '43-pl'}),
#  Document(page_content='sit amet, consectetuer adipiscing elit. Aliquam hendrerit\nmi posuere lectus.  \nVestibulum enim wisi, viverra nec, fringilla in, laoreet\nvitae, risus. Donec sit amet nisl. Aliquam semper ipsum\nsit amet velit.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '44-pl'}),
#  Document(page_content='sit amet velit.  \n2.  Suspendisse id sem consectetuer libero luctus adipiscing.  \nIt looks nice if you indent every line of the subsequent\nparagraphs, but here again, Markdown will allow you to be\nlazy:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '45-pl'}),
#  Document(page_content="lazy:  \n*   This is a list item with two paragraphs.  \nThis is the second paragraph in the list item. You're\nonly required to indent the first line. Lorem ipsum dolor\nsit amet, consectetuer adipiscing elit.  \n*   Another item in the same list.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '46-pl'}),
#  Document(page_content="To put a blockquote within a list item, the blockquote's `>`\ndelimiters need to be indented:  \n*   A list item with a blockquote:  \n> This is a blockquote\n> inside a list item.  \nTo put a code block within a list item, the code block needs", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '47-pl'}),
#  Document(page_content='to be indented *twice* -- 8 spaces or two tabs:  \n*   A list item with a code block:  \n<code goes here>  \n### Code Blocks  \nPre-formatted code blocks are used for writing about programming or', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '48-pl'}),
#  Document(page_content='markup source code. Rather than forming normal paragraphs, the lines\nof a code block are interpreted literally. Markdown wraps a code block\nin both `<pre>` and `<code>` tags.  \nTo produce a code block in Markdown, simply indent every line of the', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '49-pl'}),
#  Document(page_content='block by at least 4 spaces or 1 tab.  \nThis is a normal paragraph:  \nThis is a code block.  \nHere is an example of AppleScript:  \ntell application "Foo"\nbeep\nend tell  \nA code block continues until it reaches a line that is not indented', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '50-pl'}),
#  Document(page_content='(or the end of the article).  \nWithin a code block, ampersands (`&`) and angle brackets (`<` and `>`)\nare automatically converted into HTML entities. This makes it very\neasy to include example HTML source code using Markdown -- just paste', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '51-pl'}),
#  Document(page_content='it and indent it, and Markdown will handle the hassle of encoding the\nampersands and angle brackets. For example, this:  \n<div class="footer">\n&copy; 2004 Foo Corporation\n</div>  \nRegular Markdown syntax is not processed within code blocks. E.g.,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '52-pl'}),
#  Document(page_content='asterisks are just literal asterisks within a code block. This means\nit\'s also easy to use Markdown to write about Markdown\'s own syntax.  \n```\ntell application "Foo"\nbeep\nend tell\n```', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '53-pl'}),
#  Document(page_content='### Links  \nMarkdown supports two style of links: *inline* and *reference*.  \nIn both styles, the link text is delimited by [square brackets].  \nTo create an inline link, use a set of regular parentheses immediately', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '54-pl'}),
#  Document(page_content="after the link text's closing square bracket. Inside the parentheses,\nput the URL where you want the link to point, along with an *optional*\ntitle for the link, surrounded in quotes. For example:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '55-pl'}),
#  Document(page_content='This is [an example](http://example.com/) inline link.  \n[This link](http://example.net/) has no title attribute.  \n### Emphasis  \nMarkdown treats asterisks (`*`) and underscores (`_`) as indicators of', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '56-pl'}),
#  Document(page_content="emphasis. Text wrapped with one `*` or `_` will be wrapped with an\nHTML `<em>` tag; double `*`'s or `_`'s will be wrapped with an HTML\n`<strong>` tag. E.g., this input:  \n*single asterisks*  \n_single underscores_  \n**double asterisks**", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '57-pl'}),
#  Document(page_content='**double asterisks**  \n__double underscores__  \n### Code  \nTo indicate a span of code, wrap it with backtick quotes (`` ` ``).\nUnlike a pre-formatted code block, a code span indicates code within a\nnormal paragraph. For example:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '58-pl'}),
#  Document(page_content='Use the `printf()` function.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '59-pl'}),
#  Document(page_content="**Note:** This document is itself written using Markdown; you\ncan [see the source for it by adding '.text' to the URL](/projects/markdown/syntax.text).  \n----", metadata={'Header 1': 'Markdown: Syntax', 'source': '60-pl'}),
#  Document(page_content='### Philosophy  \nMarkdown is intended to be as easy-to-read and easy-to-write as is feasible.  \nReadability, however, is emphasized above all else. A Markdown-formatted\ndocument should be publishable as-is, as plain text, without looking', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '61-pl'}),
#  Document(page_content="like it's been marked up with tags or formatting instructions. While\nMarkdown's syntax has been influenced by several existing text-to-HTML", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '62-pl'}),
#  Document(page_content='filters -- including [Setext](http://docutils.sourceforge.net/mirror/setext.html), [atx](http://www.aaronsw.com/2002/atx/), [Textile](http://textism.com/tools/textile/), [reStructuredText](http://docutils.sourceforge.net/rst.html),', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '63-pl'}),
#  Document(page_content="[Grutatext](http://www.triptico.com/software/grutatxt.html), and [EtText](http://ettext.taint.org/doc/) -- the single biggest source of\ninspiration for Markdown's syntax is the format of plain text email.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '64-pl'}),
#  Document(page_content='### Paragraphs and Line Breaks  \nA paragraph is simply one or more consecutive lines of text, separated\nby one or more blank lines. (A blank line is any line that looks like a\nblank line -- a line containing nothing but spaces or tabs is considered', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '65-pl'}),
#  Document(page_content='blank.) Normal paragraphs should not be indented with spaces or tabs.  \nThe implication of the "one or more consecutive lines of text" rule is\nthat Markdown supports "hard-wrapped" text paragraphs. This differs', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '66-pl'}),
#  Document(page_content='significantly from most other text-to-HTML formatters (including Movable\nType\'s "Convert Line Breaks" option) which translate every line break\ncharacter in a paragraph into a `<br />` tag.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '67-pl'}),
#  Document(page_content='When you *do* want to insert a `<br />` break tag using Markdown, you\nend a line with two or more spaces, then type return.  \n### Headers  \nMarkdown supports two styles of headers, [Setext] [1] and [atx] [2].', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '68-pl'}),
#  Document(page_content='Optionally, you may "close" atx-style headers. This is purely\ncosmetic -- you can use this if you think it looks better. The\nclosing hashes don\'t even need to match the number of hashes\nused to open the header. (The number of opening hashes', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '69-pl'}),
#  Document(page_content="determines the header level.)  \n### Blockquotes  \nMarkdown uses email-style `>` characters for blockquoting. If you're\nfamiliar with quoting passages of text in an email message, then you", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '70-pl'}),
#  Document(page_content='know how to create a blockquote in Markdown. It looks best if you hard\nwrap the text and put a `>` before every line:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '71-pl'}),
#  Document(page_content='> consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\n> Vestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.\n>\n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '72-pl'}),
#  Document(page_content='> id sem consectetuer libero luctus adipiscing.  \nMarkdown allows you to be lazy and only put the `>` before the first\nline of a hard-wrapped paragraph:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '73-pl'}),
#  Document(page_content='consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\nVestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.  \n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '74-pl'}),
#  Document(page_content='id sem consectetuer libero luctus adipiscing.  \nBlockquotes can be nested (i.e. a blockquote-in-a-blockquote) by\nadding additional levels of `>`:  \n> This is the first level of quoting.\n>\n> > This is nested blockquote.\n>\n> Back to the first level.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '75-pl'}),
#  Document(page_content='> Back to the first level.  \nBlockquotes can contain other Markdown elements, including headers, lists,\nand code blocks:  \n> ## This is a header.\n>\n> 1.   This is the first list item.\n> 2.   This is the second list item.\n>', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '76-pl'}),
#  Document(page_content='>\n> Here\'s some example code:\n>\n>     return shell_exec("echo $input | $markdown_script");  \nAny decent text editor should make email-style quoting easy. For\nexample, with BBEdit, you can make a selection and choose Increase', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '77-pl'}),
#  Document(page_content='Quote Level from the Text menu.  \n### Lists  \nMarkdown supports ordered (numbered) and unordered (bulleted) lists.  \nUnordered lists use asterisks, pluses, and hyphens -- interchangably\n-- as list markers:  \n*   Red\n*   Green\n*   Blue', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '78-pl'}),
#  Document(page_content='*   Red\n*   Green\n*   Blue  \nis equivalent to:  \n+   Red\n+   Green\n+   Blue  \nand:  \n-   Red\n-   Green\n-   Blue  \nOrdered lists use numbers followed by periods:  \n1.  Bird\n2.  McHale\n3.  Parish', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '79-pl'}),
#  Document(page_content="2.  McHale\n3.  Parish  \nIt's important to note that the actual numbers you use to mark the\nlist have no effect on the HTML output Markdown produces. The HTML\nMarkdown produces from the above list is:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '80-pl'}),
#  Document(page_content="If you instead wrote the list in Markdown like this:  \n1.  Bird\n1.  McHale\n1.  Parish  \nor even:  \n3. Bird\n1. McHale\n8. Parish  \nyou'd get the exact same HTML output. The point is, if you want to,", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '81-pl'}),
#  Document(page_content="you can use ordinal numbers in your ordered Markdown lists, so that\nthe numbers in your source match the numbers in your published HTML.\nBut if you want to be lazy, you don't have to.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '82-pl'}),
#  Document(page_content='To make lists look nice, you can wrap items with hanging indents:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.\nAliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '83-pl'}),
#  Document(page_content="*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.  \nBut if you want to be lazy, you don't have to:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '84-pl'}),
#  Document(page_content='Aliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.\n*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '85-pl'}),
#  Document(page_content='List items may consist of multiple paragraphs. Each subsequent\nparagraph in a list item must be indented by either 4 spaces\nor one tab:  \n1.  This is a list item with two paragraphs. Lorem ipsum dolor', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '86-pl'}),
#  Document(page_content='sit amet, consectetuer adipiscing elit. Aliquam hendrerit\nmi posuere lectus.  \nVestibulum enim wisi, viverra nec, fringilla in, laoreet\nvitae, risus. Donec sit amet nisl. Aliquam semper ipsum\nsit amet velit.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '87-pl'}),
#  Document(page_content='sit amet velit.  \n2.  Suspendisse id sem consectetuer libero luctus adipiscing.  \nIt looks nice if you indent every line of the subsequent\nparagraphs, but here again, Markdown will allow you to be\nlazy:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '88-pl'}),
#  Document(page_content="lazy:  \n*   This is a list item with two paragraphs.  \nThis is the second paragraph in the list item. You're\nonly required to indent the first line. Lorem ipsum dolor\nsit amet, consectetuer adipiscing elit.  \n*   Another item in the same list.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '89-pl'}),
#  Document(page_content="To put a blockquote within a list item, the blockquote's `>`\ndelimiters need to be indented:  \n*   A list item with a blockquote:  \n> This is a blockquote\n> inside a list item.  \nTo put a code block within a list item, the code block needs", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '90-pl'}),
#  Document(page_content='to be indented *twice* -- 8 spaces or two tabs:  \n*   A list item with a code block:  \n<code goes here>  \n### Code Blocks  \nPre-formatted code blocks are used for writing about programming or', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '91-pl'}),
#  Document(page_content='markup source code. Rather than forming normal paragraphs, the lines\nof a code block are interpreted literally. Markdown wraps a code block\nin both `<pre>` and `<code>` tags.  \nTo produce a code block in Markdown, simply indent every line of the', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '92-pl'}),
#  Document(page_content='block by at least 4 spaces or 1 tab.  \nThis is a normal paragraph:  \nThis is a code block.  \nHere is an example of AppleScript:  \ntell application "Foo"\nbeep\nend tell  \nA code block continues until it reaches a line that is not indented', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '93-pl'}),
#  Document(page_content='(or the end of the article).  \nWithin a code block, ampersands (`&`) and angle brackets (`<` and `>`)\nare automatically converted into HTML entities. This makes it very\neasy to include example HTML source code using Markdown -- just paste', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '94-pl'}),
#  Document(page_content='it and indent it, and Markdown will handle the hassle of encoding the\nampersands and angle brackets. For example, this:  \n<div class="footer">\n&copy; 2004 Foo Corporation\n</div>  \nRegular Markdown syntax is not processed within code blocks. E.g.,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '95-pl'}),
#  Document(page_content='asterisks are just literal asterisks within a code block. This means\nit\'s also easy to use Markdown to write about Markdown\'s own syntax.  \n```\ntell application "Foo"\nbeep\nend tell\n```', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '96-pl'}),
#  Document(page_content='### Links  \nMarkdown supports two style of links: *inline* and *reference*.  \nIn both styles, the link text is delimited by [square brackets].  \nTo create an inline link, use a set of regular parentheses immediately', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '97-pl'}),
#  Document(page_content="after the link text's closing square bracket. Inside the parentheses,\nput the URL where you want the link to point, along with an *optional*\ntitle for the link, surrounded in quotes. For example:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '98-pl'}),
#  Document(page_content='This is [an example](http://example.com/) inline link.  \n[This link](http://example.net/) has no title attribute.  \n### Emphasis  \nMarkdown treats asterisks (`*`) and underscores (`_`) as indicators of', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '99-pl'}),
#  Document(page_content="emphasis. Text wrapped with one `*` or `_` will be wrapped with an\nHTML `<em>` tag; double `*`'s or `_`'s will be wrapped with an HTML\n`<strong>` tag. E.g., this input:  \n*single asterisks*  \n_single underscores_  \n**double asterisks**", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '100-pl'}),
#  Document(page_content='**double asterisks**  \n__double underscores__  \n### Code  \nTo indicate a span of code, wrap it with backtick quotes (`` ` ``).\nUnlike a pre-formatted code block, a code span indicates code within a\nnormal paragraph. For example:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '101-pl'}),
#  Document(page_content='Use the `printf()` function.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '102-pl'}),
#  Document(page_content="**Note:** This document is itself written using Markdown; you\ncan [see the source for it by adding '.text' to the URL](/projects/markdown/syntax.text).  \n----", metadata={'Header 1': 'Markdown: Syntax', 'source': '103-pl'}),
#  Document(page_content='### Philosophy  \nMarkdown is intended to be as easy-to-read and easy-to-write as is feasible.  \nReadability, however, is emphasized above all else. A Markdown-formatted\ndocument should be publishable as-is, as plain text, without looking', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '104-pl'}),
#  Document(page_content="like it's been marked up with tags or formatting instructions. While\nMarkdown's syntax has been influenced by several existing text-to-HTML", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '105-pl'}),
#  Document(page_content='filters -- including [Setext](http://docutils.sourceforge.net/mirror/setext.html), [atx](http://www.aaronsw.com/2002/atx/), [Textile](http://textism.com/tools/textile/), [reStructuredText](http://docutils.sourceforge.net/rst.html),', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '106-pl'}),
#  Document(page_content="[Grutatext](http://www.triptico.com/software/grutatxt.html), and [EtText](http://ettext.taint.org/doc/) -- the single biggest source of\ninspiration for Markdown's syntax is the format of plain text email.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '107-pl'}),
#  Document(page_content='### Paragraphs and Line Breaks  \nA paragraph is simply one or more consecutive lines of text, separated\nby one or more blank lines. (A blank line is any line that looks like a\nblank line -- a line containing nothing but spaces or tabs is considered', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '108-pl'}),
#  Document(page_content='blank.) Normal paragraphs should not be indented with spaces or tabs.  \nThe implication of the "one or more consecutive lines of text" rule is\nthat Markdown supports "hard-wrapped" text paragraphs. This differs', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '109-pl'}),
#  Document(page_content='significantly from most other text-to-HTML formatters (including Movable\nType\'s "Convert Line Breaks" option) which translate every line break\ncharacter in a paragraph into a `<br />` tag.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '110-pl'}),
#  Document(page_content='When you *do* want to insert a `<br />` break tag using Markdown, you\nend a line with two or more spaces, then type return.  \n### Headers  \nMarkdown supports two styles of headers, [Setext] [1] and [atx] [2].', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '111-pl'}),
#  Document(page_content='Optionally, you may "close" atx-style headers. This is purely\ncosmetic -- you can use this if you think it looks better. The\nclosing hashes don\'t even need to match the number of hashes\nused to open the header. (The number of opening hashes', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '112-pl'}),
#  Document(page_content="determines the header level.)  \n### Blockquotes  \nMarkdown uses email-style `>` characters for blockquoting. If you're\nfamiliar with quoting passages of text in an email message, then you", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '113-pl'}),
#  Document(page_content='know how to create a blockquote in Markdown. It looks best if you hard\nwrap the text and put a `>` before every line:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '114-pl'}),
#  Document(page_content='> consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\n> Vestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.\n>\n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '115-pl'}),
#  Document(page_content='> id sem consectetuer libero luctus adipiscing.  \nMarkdown allows you to be lazy and only put the `>` before the first\nline of a hard-wrapped paragraph:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '116-pl'}),
#  Document(page_content='consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\nVestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.  \n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '117-pl'}),
#  Document(page_content='id sem consectetuer libero luctus adipiscing.  \nBlockquotes can be nested (i.e. a blockquote-in-a-blockquote) by\nadding additional levels of `>`:  \n> This is the first level of quoting.\n>\n> > This is nested blockquote.\n>\n> Back to the first level.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '118-pl'}),
#  Document(page_content='> Back to the first level.  \nBlockquotes can contain other Markdown elements, including headers, lists,\nand code blocks:  \n> ## This is a header.\n>\n> 1.   This is the first list item.\n> 2.   This is the second list item.\n>', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '119-pl'}),
#  Document(page_content='>\n> Here\'s some example code:\n>\n>     return shell_exec("echo $input | $markdown_script");  \nAny decent text editor should make email-style quoting easy. For\nexample, with BBEdit, you can make a selection and choose Increase', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '120-pl'}),
#  Document(page_content='Quote Level from the Text menu.  \n### Lists  \nMarkdown supports ordered (numbered) and unordered (bulleted) lists.  \nUnordered lists use asterisks, pluses, and hyphens -- interchangably\n-- as list markers:  \n*   Red\n*   Green\n*   Blue', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '121-pl'}),
#  Document(page_content='*   Red\n*   Green\n*   Blue  \nis equivalent to:  \n+   Red\n+   Green\n+   Blue  \nand:  \n-   Red\n-   Green\n-   Blue  \nOrdered lists use numbers followed by periods:  \n1.  Bird\n2.  McHale\n3.  Parish', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '122-pl'}),
#  Document(page_content="2.  McHale\n3.  Parish  \nIt's important to note that the actual numbers you use to mark the\nlist have no effect on the HTML output Markdown produces. The HTML\nMarkdown produces from the above list is:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '123-pl'}),
#  Document(page_content="If you instead wrote the list in Markdown like this:  \n1.  Bird\n1.  McHale\n1.  Parish  \nor even:  \n3. Bird\n1. McHale\n8. Parish  \nyou'd get the exact same HTML output. The point is, if you want to,", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '124-pl'}),
#  Document(page_content="you can use ordinal numbers in your ordered Markdown lists, so that\nthe numbers in your source match the numbers in your published HTML.\nBut if you want to be lazy, you don't have to.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '125-pl'}),
#  Document(page_content='To make lists look nice, you can wrap items with hanging indents:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.\nAliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '126-pl'}),
#  Document(page_content="*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.  \nBut if you want to be lazy, you don't have to:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '127-pl'}),
#  Document(page_content='Aliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.\n*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '128-pl'}),
#  Document(page_content='List items may consist of multiple paragraphs. Each subsequent\nparagraph in a list item must be indented by either 4 spaces\nor one tab:  \n1.  This is a list item with two paragraphs. Lorem ipsum dolor', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '129-pl'}),
#  Document(page_content='sit amet, consectetuer adipiscing elit. Aliquam hendrerit\nmi posuere lectus.  \nVestibulum enim wisi, viverra nec, fringilla in, laoreet\nvitae, risus. Donec sit amet nisl. Aliquam semper ipsum\nsit amet velit.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '130-pl'}),
#  Document(page_content='sit amet velit.  \n2.  Suspendisse id sem consectetuer libero luctus adipiscing.  \nIt looks nice if you indent every line of the subsequent\nparagraphs, but here again, Markdown will allow you to be\nlazy:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '131-pl'}),
#  Document(page_content="lazy:  \n*   This is a list item with two paragraphs.  \nThis is the second paragraph in the list item. You're\nonly required to indent the first line. Lorem ipsum dolor\nsit amet, consectetuer adipiscing elit.  \n*   Another item in the same list.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '132-pl'}),
#  Document(page_content="To put a blockquote within a list item, the blockquote's `>`\ndelimiters need to be indented:  \n*   A list item with a blockquote:  \n> This is a blockquote\n> inside a list item.  \nTo put a code block within a list item, the code block needs", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '133-pl'}),
#  Document(page_content='to be indented *twice* -- 8 spaces or two tabs:  \n*   A list item with a code block:  \n<code goes here>  \n### Code Blocks  \nPre-formatted code blocks are used for writing about programming or', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '134-pl'}),
#  Document(page_content='markup source code. Rather than forming normal paragraphs, the lines\nof a code block are interpreted literally. Markdown wraps a code block\nin both `<pre>` and `<code>` tags.  \nTo produce a code block in Markdown, simply indent every line of the', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '135-pl'}),
#  Document(page_content='block by at least 4 spaces or 1 tab.  \nThis is a normal paragraph:  \nThis is a code block.  \nHere is an example of AppleScript:  \ntell application "Foo"\nbeep\nend tell  \nA code block continues until it reaches a line that is not indented', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '136-pl'}),
#  Document(page_content='(or the end of the article).  \nWithin a code block, ampersands (`&`) and angle brackets (`<` and `>`)\nare automatically converted into HTML entities. This makes it very\neasy to include example HTML source code using Markdown -- just paste', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '137-pl'}),
#  Document(page_content='it and indent it, and Markdown will handle the hassle of encoding the\nampersands and angle brackets. For example, this:  \n<div class="footer">\n&copy; 2004 Foo Corporation\n</div>  \nRegular Markdown syntax is not processed within code blocks. E.g.,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '138-pl'}),
#  Document(page_content='asterisks are just literal asterisks within a code block. This means\nit\'s also easy to use Markdown to write about Markdown\'s own syntax.  \n```\ntell application "Foo"\nbeep\nend tell\n```', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '139-pl'}),
#  Document(page_content='### Links  \nMarkdown supports two style of links: *inline* and *reference*.  \nIn both styles, the link text is delimited by [square brackets].  \nTo create an inline link, use a set of regular parentheses immediately', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '140-pl'}),
#  Document(page_content="after the link text's closing square bracket. Inside the parentheses,\nput the URL where you want the link to point, along with an *optional*\ntitle for the link, surrounded in quotes. For example:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '141-pl'}),
#  Document(page_content='This is [an example](http://example.com/) inline link.  \n[This link](http://example.net/) has no title attribute.  \n### Emphasis  \nMarkdown treats asterisks (`*`) and underscores (`_`) as indicators of', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '142-pl'}),
#  Document(page_content="emphasis. Text wrapped with one `*` or `_` will be wrapped with an\nHTML `<em>` tag; double `*`'s or `_`'s will be wrapped with an HTML\n`<strong>` tag. E.g., this input:  \n*single asterisks*  \n_single underscores_  \n**double asterisks**", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '143-pl'}),
#  Document(page_content='**double asterisks**  \n__double underscores__  \n### Code  \nTo indicate a span of code, wrap it with backtick quotes (`` ` ``).\nUnlike a pre-formatted code block, a code span indicates code within a\nnormal paragraph. For example:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '144-pl'}),
#  Document(page_content='Use the `printf()` function.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '145-pl'}),
# ...
#  Document(page_content="after the link text's closing square bracket. Inside the parentheses,\nput the URL where you want the link to point, along with an *optional*\ntitle for the link, surrounded in quotes. For example:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '226-pl'}),
#  Document(page_content='This is [an example](http://example.com/) inline link.  \n[This link](http://example.net/) has no title attribute.  \n### Emphasis  \nMarkdown treats asterisks (`*`) and underscores (`_`) as indicators of', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '227-pl'}),
#  Document(page_content="emphasis. Text wrapped with one `*` or `_` will be wrapped with an\nHTML `<em>` tag; double `*`'s or `_`'s will be wrapped with an HTML\n`<strong>` tag. E.g., this input:  \n*single asterisks*  \n_single underscores_  \n**double asterisks**", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '228-pl'}),
#  Document(page_content='**double asterisks**  \n__double underscores__  \n### Code  \nTo indicate a span of code, wrap it with backtick quotes (`` ` ``).\nUnlike a pre-formatted code block, a code span indicates code within a\nnormal paragraph. For example:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '229-pl'}),
#  Document(page_content="Use the `printf()` function.  \n**Note:** This document is itself written using Markdown; you\ncan [see the source for it by adding '.text' to the URL](/projects/markdown/syntax.text).  \n----", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '230-pl'}),
#  Document(page_content='### Philosophy  \nMarkdown is intended to be as easy-to-read and easy-to-write as is feasible.  \nReadability, however, is emphasized above all else. A Markdown-formatted\ndocument should be publishable as-is, as plain text, without looking', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '231-pl'}),
#  Document(page_content="like it's been marked up with tags or formatting instructions. While\nMarkdown's syntax has been influenced by several existing text-to-HTML", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '232-pl'}),
#  Document(page_content='filters -- including [Setext](http://docutils.sourceforge.net/mirror/setext.html), [atx](http://www.aaronsw.com/2002/atx/), [Textile](http://textism.com/tools/textile/), [reStructuredText](http://docutils.sourceforge.net/rst.html),', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '233-pl'}),
#  Document(page_content="[Grutatext](http://www.triptico.com/software/grutatxt.html), and [EtText](http://ettext.taint.org/doc/) -- the single biggest source of\ninspiration for Markdown's syntax is the format of plain text email.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Overview', 'source': '234-pl'}),
#  Document(page_content='### Paragraphs and Line Breaks  \nA paragraph is simply one or more consecutive lines of text, separated\nby one or more blank lines. (A blank line is any line that looks like a\nblank line -- a line containing nothing but spaces or tabs is considered', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '235-pl'}),
#  Document(page_content='blank.) Normal paragraphs should not be indented with spaces or tabs.  \nThe implication of the "one or more consecutive lines of text" rule is\nthat Markdown supports "hard-wrapped" text paragraphs. This differs', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '236-pl'}),
#  Document(page_content='significantly from most other text-to-HTML formatters (including Movable\nType\'s "Convert Line Breaks" option) which translate every line break\ncharacter in a paragraph into a `<br />` tag.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '237-pl'}),
#  Document(page_content='When you *do* want to insert a `<br />` break tag using Markdown, you\nend a line with two or more spaces, then type return.  \n### Headers  \nMarkdown supports two styles of headers, [Setext] [1] and [atx] [2].', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '238-pl'}),
#  Document(page_content='Optionally, you may "close" atx-style headers. This is purely\ncosmetic -- you can use this if you think it looks better. The\nclosing hashes don\'t even need to match the number of hashes\nused to open the header. (The number of opening hashes', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '239-pl'}),
#  Document(page_content="determines the header level.)  \n### Blockquotes  \nMarkdown uses email-style `>` characters for blockquoting. If you're\nfamiliar with quoting passages of text in an email message, then you", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '240-pl'}),
#  Document(page_content='know how to create a blockquote in Markdown. It looks best if you hard\nwrap the text and put a `>` before every line:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '241-pl'}),
#  Document(page_content='> consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\n> Vestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.\n>\n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '242-pl'}),
#  Document(page_content='> id sem consectetuer libero luctus adipiscing.  \nMarkdown allows you to be lazy and only put the `>` before the first\nline of a hard-wrapped paragraph:  \n> This is a blockquote with two paragraphs. Lorem ipsum dolor sit amet,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '243-pl'}),
#  Document(page_content='consectetuer adipiscing elit. Aliquam hendrerit mi posuere lectus.\nVestibulum enim wisi, viverra nec, fringilla in, laoreet vitae, risus.  \n> Donec sit amet nisl. Aliquam semper ipsum sit amet velit. Suspendisse', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '244-pl'}),
#  Document(page_content='id sem consectetuer libero luctus adipiscing.  \nBlockquotes can be nested (i.e. a blockquote-in-a-blockquote) by\nadding additional levels of `>`:  \n> This is the first level of quoting.\n>\n> > This is nested blockquote.\n>\n> Back to the first level.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '245-pl'}),
#  Document(page_content='> Back to the first level.  \nBlockquotes can contain other Markdown elements, including headers, lists,\nand code blocks:  \n> ## This is a header.\n>\n> 1.   This is the first list item.\n> 2.   This is the second list item.\n>', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '246-pl'}),
#  Document(page_content='>\n> Here\'s some example code:\n>\n>     return shell_exec("echo $input | $markdown_script");  \nAny decent text editor should make email-style quoting easy. For\nexample, with BBEdit, you can make a selection and choose Increase', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '247-pl'}),
#  Document(page_content='Quote Level from the Text menu.  \n### Lists  \nMarkdown supports ordered (numbered) and unordered (bulleted) lists.  \nUnordered lists use asterisks, pluses, and hyphens -- interchangably\n-- as list markers:  \n*   Red\n*   Green\n*   Blue', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '248-pl'}),
#  Document(page_content='*   Red\n*   Green\n*   Blue  \nis equivalent to:  \n+   Red\n+   Green\n+   Blue  \nand:  \n-   Red\n-   Green\n-   Blue  \nOrdered lists use numbers followed by periods:  \n1.  Bird\n2.  McHale\n3.  Parish', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '249-pl'}),
#  Document(page_content="2.  McHale\n3.  Parish  \nIt's important to note that the actual numbers you use to mark the\nlist have no effect on the HTML output Markdown produces. The HTML\nMarkdown produces from the above list is:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '250-pl'}),
#  Document(page_content="If you instead wrote the list in Markdown like this:  \n1.  Bird\n1.  McHale\n1.  Parish  \nor even:  \n3. Bird\n1. McHale\n8. Parish  \nyou'd get the exact same HTML output. The point is, if you want to,", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '251-pl'}),
#  Document(page_content="you can use ordinal numbers in your ordered Markdown lists, so that\nthe numbers in your source match the numbers in your published HTML.\nBut if you want to be lazy, you don't have to.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '252-pl'}),
#  Document(page_content='To make lists look nice, you can wrap items with hanging indents:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.\nAliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '253-pl'}),
#  Document(page_content="*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.  \nBut if you want to be lazy, you don't have to:  \n*   Lorem ipsum dolor sit amet, consectetuer adipiscing elit.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '254-pl'}),
#  Document(page_content='Aliquam hendrerit mi posuere lectus. Vestibulum enim wisi,\nviverra nec, fringilla in, laoreet vitae, risus.\n*   Donec sit amet nisl. Aliquam semper ipsum sit amet velit.\nSuspendisse id sem consectetuer libero luctus adipiscing.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '255-pl'}),
#  Document(page_content='List items may consist of multiple paragraphs. Each subsequent\nparagraph in a list item must be indented by either 4 spaces\nor one tab:  \n1.  This is a list item with two paragraphs. Lorem ipsum dolor', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '256-pl'}),
#  Document(page_content='sit amet, consectetuer adipiscing elit. Aliquam hendrerit\nmi posuere lectus.  \nVestibulum enim wisi, viverra nec, fringilla in, laoreet\nvitae, risus. Donec sit amet nisl. Aliquam semper ipsum\nsit amet velit.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '257-pl'}),
#  Document(page_content='sit amet velit.  \n2.  Suspendisse id sem consectetuer libero luctus adipiscing.  \nIt looks nice if you indent every line of the subsequent\nparagraphs, but here again, Markdown will allow you to be\nlazy:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '258-pl'}),
#  Document(page_content="lazy:  \n*   This is a list item with two paragraphs.  \nThis is the second paragraph in the list item. You're\nonly required to indent the first line. Lorem ipsum dolor\nsit amet, consectetuer adipiscing elit.  \n*   Another item in the same list.", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '259-pl'}),
#  Document(page_content="To put a blockquote within a list item, the blockquote's `>`\ndelimiters need to be indented:  \n*   A list item with a blockquote:  \n> This is a blockquote\n> inside a list item.  \nTo put a code block within a list item, the code block needs", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '260-pl'}),
#  Document(page_content='to be indented *twice* -- 8 spaces or two tabs:  \n*   A list item with a code block:  \n<code goes here>  \n### Code Blocks  \nPre-formatted code blocks are used for writing about programming or', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '261-pl'}),
#  Document(page_content='markup source code. Rather than forming normal paragraphs, the lines\nof a code block are interpreted literally. Markdown wraps a code block\nin both `<pre>` and `<code>` tags.  \nTo produce a code block in Markdown, simply indent every line of the', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '262-pl'}),
#  Document(page_content='block by at least 4 spaces or 1 tab.  \nThis is a normal paragraph:  \nThis is a code block.  \nHere is an example of AppleScript:  \ntell application "Foo"\nbeep\nend tell  \nA code block continues until it reaches a line that is not indented', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '263-pl'}),
#  Document(page_content='(or the end of the article).  \nWithin a code block, ampersands (`&`) and angle brackets (`<` and `>`)\nare automatically converted into HTML entities. This makes it very\neasy to include example HTML source code using Markdown -- just paste', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '264-pl'}),
#  Document(page_content='it and indent it, and Markdown will handle the hassle of encoding the\nampersands and angle brackets. For example, this:  \n<div class="footer">\n&copy; 2004 Foo Corporation\n</div>  \nRegular Markdown syntax is not processed within code blocks. E.g.,', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '265-pl'}),
#  Document(page_content='asterisks are just literal asterisks within a code block. This means\nit\'s also easy to use Markdown to write about Markdown\'s own syntax.  \n```\ntell application "Foo"\nbeep\nend tell\n```', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Block Elements', 'source': '266-pl'}),
#  Document(page_content='### Links  \nMarkdown supports two style of links: *inline* and *reference*.  \nIn both styles, the link text is delimited by [square brackets].  \nTo create an inline link, use a set of regular parentheses immediately', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '267-pl'}),
#  Document(page_content="after the link text's closing square bracket. Inside the parentheses,\nput the URL where you want the link to point, along with an *optional*\ntitle for the link, surrounded in quotes. For example:", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '268-pl'}),
#  Document(page_content='This is [an example](http://example.com/) inline link.  \n[This link](http://example.net/) has no title attribute.  \n### Emphasis  \nMarkdown treats asterisks (`*`) and underscores (`_`) as indicators of', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '269-pl'}),
#  Document(page_content="emphasis. Text wrapped with one `*` or `_` will be wrapped with an\nHTML `<em>` tag; double `*`'s or `_`'s will be wrapped with an HTML\n`<strong>` tag. E.g., this input:  \n*single asterisks*  \n_single underscores_  \n**double asterisks**", metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '270-pl'}),
#  Document(page_content='**double asterisks**  \n__double underscores__  \n### Code  \nTo indicate a span of code, wrap it with backtick quotes (`` ` ``).\nUnlike a pre-formatted code block, a code span indicates code within a\nnormal paragraph. For example:', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '271-pl'}),
#  Document(page_content='Use the `printf()` function.', metadata={'Header 1': 'Markdown: Syntax', 'Header 2': 'Span Elements', 'source': '272-pl'})]

# %%
# Import and instantiate OpenAI embeddings

from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model_name="ada",openai_api_key=OPENAI_API_KEY)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/langchain/embeddings/openai.py:217: UserWarning: WARNING! model_name is not default parameter.
#                     model_name was transferred to model_kwargs.
#                     Please confirm that model_name is what you intended.
#   warnings.warn(

# %%
# Turn the first text chunk into a vector with the embedding

query_result = embeddings.embed_query(splits[0].page_content)
print(query_result)

# %%
# Import and initialite Chroma
#from langchain.vectorstores import Chroma
# Import OpenSearch
from langchain.vectorstores import OpenSearchVectorSearch

# %%
# Upload vectors to Chroma

index_name = "langchain"
#search = Chroma.from_documents(splits, embeddings)
docsearch = OpenSearchVectorSearch.from_documents(
    splits, embeddings, opensearch_url="https://localhost:9200", http_auth=("admin", "admin"), verify_certs = False, index_name=index_name
)

# %%
# Do a simple vector similarity search
# Create docsearch in case that the vector database is already populated
docsearch = OpenSearchVectorSearch(
    index_name="langchain",
    embedding_function=embeddings,
    opensearch_url="https://localhost:9200", http_auth=("admin", "admin"), verify_certs = False
)
query = "Which styles of links exists in Markdown?"
result = docsearch.similarity_search(query, k=10)

print(result[1].page_content)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/opensearchpy/connection/http_urllib3.py:199: UserWarning: Connecting to https://localhost:9200 using SSL with verify_certs=False is insecure.
#   warnings.warn(
# ### Links
# Markdown supports two style of links: *inline* and *reference*.
# In both styles, the link text is delimited by [square brackets].
# To create an inline link, use a set of regular parentheses immediately
# /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
